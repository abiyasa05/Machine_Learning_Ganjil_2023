# %% [markdown]
# <a href="https://colab.research.google.com/github/abiyasa05/Machine_Learning_Ganjil_2023/blob/main/Jobsheet_11_Convolutional_Neural_Network_(CNN).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Link GIthub: (https://github.com/abiyasa05/Machine_Learning_Ganjil_2023/blob/main/Jobsheet_11_Convolutional_Neural_Network_(CNN).ipynb)

# %% [markdown]
# # **Praktikum 1**
#
# Klasifikasi 🐱 dan 🐶

# %% [markdown]
# # **Deskripsi**
#
# Pada praktikum ini kita akan membuat model klasifikasi CNN sederhana pada kasus citra kucing dan anjing.

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # **Langkah 1 - Import Library**

# %%
import tensorflow as tf
from keras.preprocessing.image import ImageDataGenerator

# %% [markdown]
# # **Langkah 2 - Pra Pengolahan Data**
#
# Pada tahap ini kita akan sedikit melakukan manipulasi pada citra yang digunakan. Manipulasi yang dilakukan diantaranya adalah normalisasi nilai piksel, koreksi kemiringan, pembesaran (zoom), dan flip.

# %% [markdown]
# # **Langkah 2.1. Pra Pengolahan Data Training**

# %%
train_datagen = ImageDataGenerator(rescale = 1./255,
                                   shear_range = 0.2,
                                   zoom_range = 0.2,
                                   horizontal_flip = True)
training_set = train_datagen.flow_from_directory('/content/drive/MyDrive/Machine Learning/dataset/training_set',
                                                 target_size = (64, 64),
                                                 batch_size = 32,
                                                 class_mode = 'binary')
# Out:
# Found 8010 images belonging to 2 classes.

# %% [markdown]
# # **Langkah 2.2. Pra Pengolahan Data Testing**

# %%
test_datagen = ImageDataGenerator(rescale = 1./255)
test_set = test_datagen.flow_from_directory('/content/drive/MyDrive/Machine Learning/dataset/test_set',
                                            target_size = (64, 64),
                                            batch_size = 32,
                                            class_mode = 'binary')
# Out:
# Found 2000 images belonging to 2 classes.

# %% [markdown]
# # **Langkah 3 - Pembuatan Model CNN**

# %% [markdown]
# # **Langkah 3.1.  - Inisiasi Model CNN**

# %%
cnn = tf.keras.models.Sequential()

# %% [markdown]
# # **Langkah 3.2. - Pembuatan Layer Konvolusi 1**

# %%
cnn.add(tf.keras.layers.Conv2D(filters=32, kernel_size=3, activation='relu', input_shape=[64, 64, 3]))

# %% [markdown]
# # **Langkah 3.3 - Pembuatan Layer Pooling 1**

# %%
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2, strides=2))

# %% [markdown]
# # **Langkah 3.4 - Pembuatan Layer Konvolusi 2 dan Pooling 2**

# %%
cnn.add(tf.keras.layers.Conv2D(filters=32, kernel_size=3, activation='relu'))
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2, strides=2))

# %% [markdown]
# # **Langkah 3.5 - Flattening**

# %%
cnn.add(tf.keras.layers.Flatten())

# %% [markdown]
# # **Langkah 3.6 - Fully Connected Layer 1 (Input)**

# %%
cnn.add(tf.keras.layers.Dense(units=128, activation='relu'))

# %% [markdown]
# # **Langkah 3.7 - Fully Connected Layer 2 (Output)**

# %%
cnn.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# %% [markdown]
# # **Langkah 3.8 - Compile Model CNN**

# %%
cnn.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %% [markdown]
# Penggunaan loss function binary crossentropy dikarenakan kita hanya melakukan klasifikasi pada dua kelas, yaitu kucing dan anjing.

# %% [markdown]
# # **Langkah 4 - Fit CNN**

# %%
cnn.fit(x = training_set, validation_data = test_set, epochs = 25)
# Out:
# Epoch 1/25
# 251/251 [==============================] - 2577s 10s/step - loss: 0.6763 - accuracy: 0.5798 - val_loss: 0.6349 - val_accuracy: 0.6480
# Epoch 2/25
# 251/251 [==============================] - 43s 171ms/step - loss: 0.6137 - accuracy: 0.6667 - val_loss: 0.5961 - val_accuracy: 0.6735
# Epoch 3/25
# 251/251 [==============================] - 38s 153ms/step - loss: 0.5704 - accuracy: 0.7007 - val_loss: 0.5619 - val_accuracy: 0.7240
# Epoch 4/25
# 251/251 [==============================] - 38s 151ms/step - loss: 0.5342 - accuracy: 0.7328 - val_loss: 0.5179 - val_accuracy: 0.7565
# Epoch 5/25
# 251/251 [==============================] - 39s 154ms/step - loss: 0.5088 - accuracy: 0.7521 - val_loss: 0.4914 - val_accuracy: 0.7680
# Epoch 6/25
# 251/251 [==============================] - 39s 154ms/step - loss: 0.4831 - accuracy: 0.7647 - val_loss: 0.4736 - val_accuracy: 0.7855
# Epoch 7/25
# 251/251 [==============================] - 38s 150ms/step - loss: 0.4615 - accuracy: 0.7760 - val_loss: 0.4953 - val_accuracy: 0.7750
# Epoch 8/25
# 251/251 [==============================] - 43s 171ms/step - loss: 0.4529 - accuracy: 0.7841 - val_loss: 0.4666 - val_accuracy: 0.7950
# Epoch 9/25
# 251/251 [==============================] - 38s 151ms/step - loss: 0.4277 - accuracy: 0.8017 - val_loss: 0.4543 - val_accuracy: 0.8010
# Epoch 10/25
# 251/251 [==============================] - 38s 153ms/step - loss: 0.4174 - accuracy: 0.8071 - val_loss: 0.5037 - val_accuracy: 0.7705
# Epoch 11/25
# 251/251 [==============================] - 38s 152ms/step - loss: 0.3965 - accuracy: 0.8212 - val_loss: 0.4823 - val_accuracy: 0.7960
# Epoch 12/25
# 251/251 [==============================] - 39s 156ms/step - loss: 0.3856 - accuracy: 0.8189 - val_loss: 0.4452 - val_accuracy: 0.8055
# Epoch 13/25
# 251/251 [==============================] - 38s 151ms/step - loss: 0.3638 - accuracy: 0.8355 - val_loss: 0.4626 - val_accuracy: 0.7935
# Epoch 14/25
# 251/251 [==============================] - 38s 150ms/step - loss: 0.3516 - accuracy: 0.8427 - val_loss: 0.4947 - val_accuracy: 0.7955
# Epoch 15/25
# 251/251 [==============================] - 38s 153ms/step - loss: 0.3444 - accuracy: 0.8442 - val_loss: 0.4657 - val_accuracy: 0.8040
# Epoch 16/25
# 251/251 [==============================] - 43s 171ms/step - loss: 0.3248 - accuracy: 0.8543 - val_loss: 0.4591 - val_accuracy: 0.8035
# Epoch 17/25
# 251/251 [==============================] - 43s 173ms/step - loss: 0.3094 - accuracy: 0.8624 - val_loss: 0.5117 - val_accuracy: 0.7900
# Epoch 18/25
# 251/251 [==============================] - 40s 158ms/step - loss: 0.3021 - accuracy: 0.8653 - val_loss: 0.4933 - val_accuracy: 0.8035
# Epoch 19/25
# 251/251 [==============================] - 38s 152ms/step - loss: 0.2837 - accuracy: 0.8825 - val_loss: 0.5370 - val_accuracy: 0.7855
# Epoch 20/25
# 251/251 [==============================] - 40s 158ms/step - loss: 0.2700 - accuracy: 0.8859 - val_loss: 0.5076 - val_accuracy: 0.8025
# Epoch 21/25
# 251/251 [==============================] - 40s 157ms/step - loss: 0.2623 - accuracy: 0.8911 - val_loss: 0.5080 - val_accuracy: 0.8095
# Epoch 22/25
# 251/251 [==============================] - 43s 173ms/step - loss: 0.2583 - accuracy: 0.8954 - val_loss: 0.5013 - val_accuracy: 0.8095
# Epoch 23/25
# 251/251 [==============================] - 39s 156ms/step - loss: 0.2352 - accuracy: 0.9024 - val_loss: 0.5505 - val_accuracy: 0.8040
# Epoch 24/25
# 251/251 [==============================] - 38s 153ms/step - loss: 0.2270 - accuracy: 0.9035 - val_loss: 0.6217 - val_accuracy: 0.7945
# Epoch 25/25
# 251/251 [==============================] - 39s 157ms/step - loss: 0.2132 - accuracy: 0.9092 - val_loss: 0.6110 - val_accuracy: 0.8025

# %% [markdown]
# # **Langkah 5 - Prediksi dengan 1 Citra**

# %%
import numpy as np
from keras.preprocessing import image
test_image = image.load_img('/content/drive/MyDrive/Machine Learning/dataset/single_prediction/cat_or_dog_1.jpg', target_size = (64, 64))
test_image = image.img_to_array(test_image)
test_image = np.expand_dims(test_image, axis = 0)
result = cnn.predict(test_image)
training_set.class_indices
if result[0][0] == 1:
  prediction = 'dog'
else:
  prediction = 'cat'
# Out:
# 1/1 [==============================] - 0s 163ms/step

# %% [markdown]
# # **Praktikum 2**
#
# Klasifikasi Multi-label dengan Data CIFAT

# %% [markdown]
# # **Deskripsi**
#
# Pada praktikum ini kita akan membuat model CNN untuk mengklasifikasikan 10 objek dari dataset CIFAR. Dataset terdiri dari 60.000 citra dan setiap label terdiri dari 6.000 citra. Dataset telah dibagi menjadi 50.000 data training dan 10.000 data testing.

# %% [markdown]
# # **Langkah 1 - Load Library**

# %%
import tensorflow as tf

from tensorflow.keras import datasets, layers, models
import matplotlib.pyplot as plt

# %% [markdown]
# # **Langkah 2 - Unduh Dataset CIFAR**

# %%
(train_images, train_labels), (test_images, test_labels) = datasets.cifar10.load_data()

# Normalize pixel values to be between 0 and 1
train_images, test_images = train_images / 255.0, test_images / 255.0
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 7s 0us/step

# %% [markdown]
# # **Langkah 3 - Verifikasi Data**

# %%
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer',
               'dog', 'frog', 'horse', 'ship', 'truck']

plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(train_images[i])
    # The CIFAR labels happen to be arrays,
    # which is why you need the extra index
    plt.xlabel(class_names[train_labels[i][0]])
plt.show()

# %% [markdown]
# # **Langkah 4 - Buat Model CNN**
#
# # **Langkah 4.1. - Buat Layer Konvolusi**

# %%
model = models.Sequential()
model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3)))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))

# %% [markdown]
# # **Langkah 4.2. - Cek Arsitektur Konvolusi**

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_2 (Conv2D)           (None, 30, 30, 32)        896
#
#  max_pooling2d_2 (MaxPoolin  (None, 15, 15, 32)        0
#  g2D)
#
#  conv2d_3 (Conv2D)           (None, 13, 13, 64)        18496
#
#  max_pooling2d_3 (MaxPoolin  (None, 6, 6, 64)          0
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 4, 4, 64)          36928
#
# =================================================================
# Total params: 56320 (220.00 KB)
# Trainable params: 56320 (220.00 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# # **Langkah 4.3. - Tambahkan Layer Fully Connected**

# %%
model.add(layers.Flatten())
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(10))

# %% [markdown]
# # **Langkah 4.4. - Cek Arsitektur Model CNN**

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_2 (Conv2D)           (None, 30, 30, 32)        896
#
#  max_pooling2d_2 (MaxPoolin  (None, 15, 15, 32)        0
#  g2D)
#
#  conv2d_3 (Conv2D)           (None, 13, 13, 64)        18496
#
#  max_pooling2d_3 (MaxPoolin  (None, 6, 6, 64)          0
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 4, 4, 64)          36928
#
#  flatten_1 (Flatten)         (None, 1024)              0
#
#  dense_2 (Dense)             (None, 64)                65600
#
#  dense_3 (Dense)             (None, 10)                650
#
# =================================================================
# Total params: 122570 (478.79 KB)
# Trainable params: 122570 (478.79 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# # **Langkah 4.5. - Compile Model CNN**

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %% [markdown]
# # **Langkah 5 - Fit Model**

# %%
history = model.fit(train_images, train_labels, epochs=10,
                    validation_data=(test_images, test_labels))
# Out:
# Epoch 1/10
# 1563/1563 [==============================] - 12s 6ms/step - loss: 1.5142 - accuracy: 0.4456 - val_loss: 1.2581 - val_accuracy: 0.5475
# Epoch 2/10
# 1563/1563 [==============================] - 9s 5ms/step - loss: 1.1771 - accuracy: 0.5816 - val_loss: 1.1383 - val_accuracy: 0.5964
# Epoch 3/10
# 1563/1563 [==============================] - 8s 5ms/step - loss: 1.0186 - accuracy: 0.6406 - val_loss: 1.0123 - val_accuracy: 0.6428
# Epoch 4/10
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.9160 - accuracy: 0.6793 - val_loss: 0.9319 - val_accuracy: 0.6804
# Epoch 5/10
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.8428 - accuracy: 0.7056 - val_loss: 0.8891 - val_accuracy: 0.6952
# Epoch 6/10
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.7803 - accuracy: 0.7265 - val_loss: 0.9196 - val_accuracy: 0.6854
# Epoch 7/10
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.7335 - accuracy: 0.7419 - val_loss: 0.8702 - val_accuracy: 0.7031
# Epoch 8/10
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.6889 - accuracy: 0.7580 - val_loss: 0.8666 - val_accuracy: 0.7067
# Epoch 9/10
# 1563/1563 [==============================] - 10s 6ms/step - loss: 0.6543 - accuracy: 0.7683 - val_loss: 0.8248 - val_accuracy: 0.7159
# Epoch 10/10
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.6117 - accuracy: 0.7844 - val_loss: 0.8693 - val_accuracy: 0.7085

# %% [markdown]
# # **Langkah 6 - Evaluasi Model**

# %%
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0.5, 1])
plt.legend(loc='lower right')

test_loss, test_acc = model.evaluate(test_images,  test_labels, verbose=2)
# Out:
# 313/313 - 1s - loss: 0.8693 - accuracy: 0.7085 - 975ms/epoch - 3ms/step

# %% [markdown]
# # **Langkah 7 - Cetak Hasil Akurasi**

# %%
print(test_acc)
# Out:
# 0.7085000276565552

# %% [markdown]
# # **Tugas**

# %% [markdown]
# -   Modifikasi model CNN pada praktikum 2 sehingga didapatkan akurasi testing lebih dari 80%.

# %% [markdown]
# # **Langkah 1: Impor pustaka dan modul yang diperlukan**

# %%
from tensorflow.keras.datasets import cifar10
import numpy as np
import pandas as pd
import pickle
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import utils
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Conv2D, Dropout, MaxPooling2D, GlobalAveragePooling2D, Activation, BatchNormalization
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import regularizers
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt
from PIL import Image

# %% [markdown]
# # **Langkah 2: Memuat dataset CIFAR-10**

# %%
(X_train, y_train), (X_test, y_test) = cifar10.load_data()
print('Training set shape:', X_train.shape)
print('Test set shape:', X_test.shape)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 4s 0us/step
# Training set shape: (50000, 32, 32, 3)
# Test set shape: (10000, 32, 32, 3)

# %% [markdown]
# # **Langkah 3: Normalisasi data dan konversi label ke vektor one-hot encoded**

# %%
X_train = X_train.astype('float32') / 255.0
X_test = X_test.astype('float32') / 255.0
num_classes = 10
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# %% [markdown]
# # **Langkah 4: Memisahkan data latih menjadi data latih dan data validasi**

# %%
X_train, X_valid, y_train, y_valid = train_test_split(X_train, y_train, test_size=0.2, random_state=42)

# %% [markdown]
# # **Langkah 5: Mendefinisikan model Convolutional Neural Network (CNN)**

# %%
def cnn_model():
    model = Sequential()
    # First Conv layer
    model.add(Conv2D(filters=128, kernel_size=(3,3), activation='relu', padding='same', kernel_regularizer=regularizers.l2(1e-4), input_shape=(32,32,3)))
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Dropout(0.3))

    # Second Conv layer
    model.add(Conv2D(filters=256, kernel_size=(3,3), activation='relu', padding='same', kernel_regularizer=regularizers.l2(1e-4)))
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Dropout(0.3))

    # Third, fourth, fifth convolution layer
    model.add(Conv2D(filters=512, kernel_size=(3,3), activation='relu', padding='same', kernel_regularizer=regularizers.l2(1e-4)))
    model.add(Conv2D(filters=512, kernel_size=(3,3), activation='relu', padding='same', kernel_regularizer=regularizers.l2(1e-4)))
    model.add(Conv2D(filters=256, kernel_size=(3,3), activation='relu', padding='same', kernel_regularizer=regularizers.l2(1e-4)))
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Dropout(0.3))

    # Fully Connected layers
    model.add(Flatten())

    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(256, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(128, activation='relu'))
    model.add(Dropout(0.5))

    model.add(Dense(10, activation='softmax'))

    model.summary()

    return model

# %% [markdown]
# # **Langkah 6: Membuat objek ImageDataGenerator dan mempersiapkan augmentasi data**

# %%
datagen = ImageDataGenerator(
    featurewise_center=False,
    samplewise_center=False,
    featurewise_std_normalization=False,
    samplewise_std_normalization=False,
    zca_whitening=False,
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True,
    vertical_flip=False
)
datagen.fit(X_train)

# %% [markdown]
# # **Langkah 7: Membuat model dan mengompilasi**

# %%
model = cnn_model()
model.compile(
    loss='categorical_crossentropy',
    optimizer=Adam(learning_rate=0.0003),
    metrics=['accuracy']
)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 32, 32, 128)       3584
#
#  max_pooling2d (MaxPooling2  (None, 16, 16, 128)       0
#  D)
#
#  dropout (Dropout)           (None, 16, 16, 128)       0
#
#  conv2d_1 (Conv2D)           (None, 16, 16, 256)       295168
#
#  max_pooling2d_1 (MaxPoolin  (None, 8, 8, 256)         0
#  g2D)
#
#  dropout_1 (Dropout)         (None, 8, 8, 256)         0
#
#  conv2d_2 (Conv2D)           (None, 8, 8, 512)         1180160
#
#  conv2d_3 (Conv2D)           (None, 8, 8, 512)         2359808
#
#  conv2d_4 (Conv2D)           (None, 8, 8, 256)         1179904
#
#  max_pooling2d_2 (MaxPoolin  (None, 4, 4, 256)         0
#  g2D)
#
#  dropout_2 (Dropout)         (None, 4, 4, 256)         0
#
#  flatten (Flatten)           (None, 4096)              0
#
#  dense (Dense)               (None, 512)               2097664
#
#  dropout_3 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 256)               131328
#
#  dropout_4 (Dropout)         (None, 256)               0
#
#  dense_2 (Dense)             (None, 128)               32896
#
#  dropout_5 (Dropout)         (None, 128)               0
#
#  dense_3 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 7281802 (27.78 MB)
# Trainable params: 7281802 (27.78 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# # **Langkah 8: Melatih model dengan ImageDataGenerator**

# %%
history = model.fit(
    datagen.flow(X_train, y_train, batch_size=64),
    steps_per_epoch=len(X_train) // 64,
    epochs=125,
    validation_data=(X_valid, y_valid),
    verbose=1
)
# Out:
# Epoch 1/125
# 625/625 [==============================] - 51s 60ms/step - loss: 2.1542 - accuracy: 0.1987 - val_loss: 1.7714 - val_accuracy: 0.3541
# Epoch 2/125
# 625/625 [==============================] - 33s 53ms/step - loss: 1.7352 - accuracy: 0.3552 - val_loss: 1.4966 - val_accuracy: 0.4608
# Epoch 3/125
# 625/625 [==============================] - 33s 53ms/step - loss: 1.5526 - accuracy: 0.4361 - val_loss: 1.3362 - val_accuracy: 0.5219
# Epoch 4/125
# 625/625 [==============================] - 32s 51ms/step - loss: 1.4190 - accuracy: 0.5030 - val_loss: 1.3133 - val_accuracy: 0.5374
# Epoch 5/125
# 625/625 [==============================] - 33s 53ms/step - loss: 1.3195 - accuracy: 0.5469 - val_loss: 1.2111 - val_accuracy: 0.5764
# Epoch 6/125
# 625/625 [==============================] - 33s 52ms/step - loss: 1.2369 - accuracy: 0.5816 - val_loss: 1.0696 - val_accuracy: 0.6393
# Epoch 7/125
# 625/625 [==============================] - 33s 53ms/step - loss: 1.1705 - accuracy: 0.6097 - val_loss: 1.0597 - val_accuracy: 0.6385
# Epoch 8/125
# 625/625 [==============================] - 34s 55ms/step - loss: 1.1178 - accuracy: 0.6315 - val_loss: 0.9816 - val_accuracy: 0.6695
# Epoch 9/125
# 625/625 [==============================] - 33s 53ms/step - loss: 1.0803 - accuracy: 0.6506 - val_loss: 0.9792 - val_accuracy: 0.6770
# Epoch 10/125
# 625/625 [==============================] - 32s 51ms/step - loss: 1.0328 - accuracy: 0.6662 - val_loss: 0.8636 - val_accuracy: 0.7184
# Epoch 11/125
# 625/625 [==============================] - 32s 51ms/step - loss: 1.0061 - accuracy: 0.6796 - val_loss: 0.9303 - val_accuracy: 0.6935
# Epoch 12/125
# 625/625 [==============================] - 31s 50ms/step - loss: 0.9731 - accuracy: 0.6924 - val_loss: 0.8407 - val_accuracy: 0.7284
# Epoch 13/125
# 625/625 [==============================] - 32s 52ms/step - loss: 0.9517 - accuracy: 0.7020 - val_loss: 0.7876 - val_accuracy: 0.7468
# Epoch 14/125
# 625/625 [==============================] - 32s 50ms/step - loss: 0.9218 - accuracy: 0.7142 - val_loss: 0.7826 - val_accuracy: 0.7529
# Epoch 15/125
# 625/625 [==============================] - 37s 59ms/step - loss: 0.8980 - accuracy: 0.7236 - val_loss: 0.7905 - val_accuracy: 0.7512
# Epoch 16/125
# 625/625 [==============================] - 32s 51ms/step - loss: 0.8761 - accuracy: 0.7314 - val_loss: 0.8551 - val_accuracy: 0.7357
# Epoch 17/125
# 625/625 [==============================] - 32s 52ms/step - loss: 0.8617 - accuracy: 0.7410 - val_loss: 0.7052 - val_accuracy: 0.7843
# Epoch 18/125
# 625/625 [==============================] - 33s 53ms/step - loss: 0.8478 - accuracy: 0.7455 - val_loss: 0.7050 - val_accuracy: 0.7854
# Epoch 19/125
# 625/625 [==============================] - 33s 52ms/step - loss: 0.8278 - accuracy: 0.7566 - val_loss: 0.7629 - val_accuracy: 0.7713
# Epoch 20/125
# 625/625 [==============================] - 33s 52ms/step - loss: 0.8132 - accuracy: 0.7605 - val_loss: 0.7154 - val_accuracy: 0.7895
# Epoch 21/125
# 625/625 [==============================] - 37s 59ms/step - loss: 0.8051 - accuracy: 0.7655 - val_loss: 0.6823 - val_accuracy: 0.7957
# Epoch 22/125
# 625/625 [==============================] - 33s 52ms/step - loss: 0.7886 - accuracy: 0.7702 - val_loss: 0.6670 - val_accuracy: 0.8053
# Epoch 23/125
# 625/625 [==============================] - 33s 52ms/step - loss: 0.7711 - accuracy: 0.7772 - val_loss: 0.7271 - val_accuracy: 0.7872
# Epoch 24/125
# 625/625 [==============================] - 36s 57ms/step - loss: 0.7627 - accuracy: 0.7808 - val_loss: 0.6688 - val_accuracy: 0.8039
# Epoch 25/125
# 625/625 [==============================] - 33s 53ms/step - loss: 0.7516 - accuracy: 0.7871 - val_loss: 0.6729 - val_accuracy: 0.8050
# Epoch 26/125
# 625/625 [==============================] - 33s 53ms/step - loss: 0.7362 - accuracy: 0.7903 - val_loss: 0.6044 - val_accuracy: 0.8293
# Epoch 27/125
# 625/625 [==============================] - 32s 51ms/step - loss: 0.7306 - accuracy: 0.7939 - val_loss: 0.6822 - val_accuracy: 0.8053
# Epoch 28/125
# 625/625 [==============================] - 37s 60ms/step - loss: 0.7284 - accuracy: 0.7965 - val_loss: 0.6610 - val_accuracy: 0.8127
# Epoch 29/125
# 625/625 [==============================] - 37s 59ms/step - loss: 0.7128 - accuracy: 0.8023 - val_loss: 0.6101 - val_accuracy: 0.8281
# Epoch 30/125
# 625/625 [==============================] - 39s 63ms/step - loss: 0.7130 - accuracy: 0.8066 - val_loss: 0.6455 - val_accuracy: 0.8210
# Epoch 31/125
# 625/625 [==============================] - 33s 53ms/step - loss: 0.6995 - accuracy: 0.8084 - val_loss: 0.6603 - val_accuracy: 0.8162
# Epoch 32/125
# 625/625 [==============================] - 32s 52ms/step - loss: 0.6974 - accuracy: 0.8095 - val_loss: 0.6529 - val_accuracy: 0.8225
# Epoch 33/125
# 625/625 [==============================] - 36s 58ms/step - loss: 0.6822 - accuracy: 0.8156 - val_loss: 0.6263 - val_accuracy: 0.8288
# Epoch 34/125
# 625/625 [==============================] - 43s 68ms/step - loss: 0.6854 - accuracy: 0.8167 - val_loss: 0.6170 - val_accuracy: 0.8353
# Epoch 35/125
# 625/625 [==============================] - 39s 63ms/step - loss: 0.6781 - accuracy: 0.8152 - val_loss: 0.6336 - val_accuracy: 0.8298
# Epoch 36/125
# 625/625 [==============================] - 46s 73ms/step - loss: 0.6742 - accuracy: 0.8212 - val_loss: 0.6478 - val_accuracy: 0.8258
# Epoch 37/125
# 625/625 [==============================] - 45s 71ms/step - loss: 0.6611 - accuracy: 0.8227 - val_loss: 0.6901 - val_accuracy: 0.8141
# Epoch 38/125
# 625/625 [==============================] - 35s 55ms/step - loss: 0.6614 - accuracy: 0.8249 - val_loss: 0.7287 - val_accuracy: 0.7997
# Epoch 39/125
# 625/625 [==============================] - 33s 52ms/step - loss: 0.6602 - accuracy: 0.8243 - val_loss: 0.6803 - val_accuracy: 0.8197
# Epoch 40/125
# 625/625 [==============================] - 32s 52ms/step - loss: 0.6460 - accuracy: 0.8323 - val_loss: 0.6270 - val_accuracy: 0.8395
# Epoch 41/125
# 625/625 [==============================] - 33s 52ms/step - loss: 0.6480 - accuracy: 0.8315 - val_loss: 0.6403 - val_accuracy: 0.8302
# Epoch 42/125
# 625/625 [==============================] - 34s 54ms/step - loss: 0.6420 - accuracy: 0.8346 - val_loss: 0.6208 - val_accuracy: 0.8407
# Epoch 43/125
# 625/625 [==============================] - 32s 52ms/step - loss: 0.6421 - accuracy: 0.8321 - val_loss: 0.6195 - val_accuracy: 0.8374
# Epoch 44/125
# 625/625 [==============================] - 33s 53ms/step - loss: 0.6288 - accuracy: 0.8364 - val_loss: 0.6564 - val_accuracy: 0.8303
# Epoch 45/125
# 625/625 [==============================] - 31s 50ms/step - loss: 0.6314 - accuracy: 0.8391 - val_loss: 0.6230 - val_accuracy: 0.8395
# Epoch 46/125
# 625/625 [==============================] - 32s 50ms/step - loss: 0.6326 - accuracy: 0.8390 - val_loss: 0.6342 - val_accuracy: 0.8351
# Epoch 47/125
# 625/625 [==============================] - 33s 52ms/step - loss: 0.6271 - accuracy: 0.8408 - val_loss: 0.6541 - val_accuracy: 0.8333
# Epoch 48/125
# 625/625 [==============================] - 32s 52ms/step - loss: 0.6225 - accuracy: 0.8425 - val_loss: 0.6695 - val_accuracy: 0.8268
# Epoch 49/125
# 625/625 [==============================] - 33s 52ms/step - loss: 0.6170 - accuracy: 0.8464 - val_loss: 0.6097 - val_accuracy: 0.8470
# Epoch 50/125
# 625/625 [==============================] - 32s 51ms/step - loss: 0.6109 - accuracy: 0.8485 - val_loss: 0.6421 - val_accuracy: 0.8394
# Epoch 51/125
# 625/625 [==============================] - 33s 52ms/step - loss: 0.6181 - accuracy: 0.8456 - val_loss: 0.6643 - val_accuracy: 0.8369
# Epoch 52/125
# 625/625 [==============================] - 33s 53ms/step - loss: 0.6080 - accuracy: 0.8495 - val_loss: 0.6603 - val_accuracy: 0.8329
# Epoch 53/125
# 625/625 [==============================] - 33s 53ms/step - loss: 0.6196 - accuracy: 0.8484 - val_loss: 0.6334 - val_accuracy: 0.8498
# Epoch 54/125
# 625/625 [==============================] - 33s 52ms/step - loss: 0.6057 - accuracy: 0.8521 - val_loss: 0.6233 - val_accuracy: 0.8510
# Epoch 55/125
# 625/625 [==============================] - 31s 50ms/step - loss: 0.6046 - accuracy: 0.8538 - val_loss: 0.6278 - val_accuracy: 0.8453
# Epoch 56/125
# 625/625 [==============================] - 33s 52ms/step - loss: 0.6034 - accuracy: 0.8540 - val_loss: 0.6211 - val_accuracy: 0.8473
# Epoch 57/125
# 625/625 [==============================] - 31s 50ms/step - loss: 0.5984 - accuracy: 0.8564 - val_loss: 0.6837 - val_accuracy: 0.8312
# Epoch 58/125
# 625/625 [==============================] - 33s 52ms/step - loss: 0.5976 - accuracy: 0.8549 - val_loss: 0.6365 - val_accuracy: 0.8435
# Epoch 59/125
# 625/625 [==============================] - 46s 74ms/step - loss: 0.5960 - accuracy: 0.8566 - val_loss: 0.6445 - val_accuracy: 0.8432
# Epoch 60/125
# 625/625 [==============================] - 33s 53ms/step - loss: 0.6073 - accuracy: 0.8547 - val_loss: 0.6191 - val_accuracy: 0.8513
# Epoch 61/125
# 625/625 [==============================] - 37s 59ms/step - loss: 0.5899 - accuracy: 0.8589 - val_loss: 0.6114 - val_accuracy: 0.8534
# Epoch 62/125
# 625/625 [==============================] - 41s 65ms/step - loss: 0.5909 - accuracy: 0.8598 - val_loss: 0.6477 - val_accuracy: 0.8447
# Epoch 63/125
# 625/625 [==============================] - 41s 65ms/step - loss: 0.5891 - accuracy: 0.8618 - val_loss: 0.6286 - val_accuracy: 0.8475
# Epoch 64/125
# 625/625 [==============================] - 52s 84ms/step - loss: 0.5893 - accuracy: 0.8608 - val_loss: 0.6442 - val_accuracy: 0.8477
# Epoch 65/125
# 625/625 [==============================] - 33s 52ms/step - loss: 0.5853 - accuracy: 0.8633 - val_loss: 0.6146 - val_accuracy: 0.8534
# Epoch 66/125
# 625/625 [==============================] - 35s 56ms/step - loss: 0.5841 - accuracy: 0.8630 - val_loss: 0.6414 - val_accuracy: 0.8528
# Epoch 67/125
# 625/625 [==============================] - 32s 51ms/step - loss: 0.5943 - accuracy: 0.8626 - val_loss: 0.6309 - val_accuracy: 0.8492
# Epoch 68/125
# 625/625 [==============================] - 33s 53ms/step - loss: 0.5877 - accuracy: 0.8639 - val_loss: 0.6625 - val_accuracy: 0.8439
# Epoch 69/125
# 625/625 [==============================] - 31s 50ms/step - loss: 0.5758 - accuracy: 0.8684 - val_loss: 0.6643 - val_accuracy: 0.8389
# Epoch 70/125
# 625/625 [==============================] - 32s 52ms/step - loss: 0.5698 - accuracy: 0.8683 - val_loss: 0.7183 - val_accuracy: 0.8312
# Epoch 71/125
# 625/625 [==============================] - 32s 50ms/step - loss: 0.5754 - accuracy: 0.8676 - val_loss: 0.6281 - val_accuracy: 0.8534
# Epoch 72/125
# 625/625 [==============================] - 31s 50ms/step - loss: 0.5862 - accuracy: 0.8644 - val_loss: 0.5995 - val_accuracy: 0.8602
# Epoch 73/125
# 625/625 [==============================] - 33s 52ms/step - loss: 0.5794 - accuracy: 0.8676 - val_loss: 0.6804 - val_accuracy: 0.8390
# Epoch 74/125
# 625/625 [==============================] - 31s 50ms/step - loss: 0.5745 - accuracy: 0.8690 - val_loss: 0.6093 - val_accuracy: 0.8587
# Epoch 75/125
# 625/625 [==============================] - 32s 52ms/step - loss: 0.5697 - accuracy: 0.8702 - val_loss: 0.6331 - val_accuracy: 0.8517
# Epoch 76/125
# 625/625 [==============================] - 32s 51ms/step - loss: 0.5756 - accuracy: 0.8701 - val_loss: 0.6408 - val_accuracy: 0.8517
# Epoch 77/125
# 625/625 [==============================] - 32s 51ms/step - loss: 0.5760 - accuracy: 0.8679 - val_loss: 0.6274 - val_accuracy: 0.8546
# Epoch 78/125
# 625/625 [==============================] - 32s 51ms/step - loss: 0.5672 - accuracy: 0.8738 - val_loss: 0.6593 - val_accuracy: 0.8501
# Epoch 79/125
# 625/625 [==============================] - 33s 52ms/step - loss: 0.5733 - accuracy: 0.8705 - val_loss: 0.6185 - val_accuracy: 0.8592
# Epoch 80/125
# 625/625 [==============================] - 33s 52ms/step - loss: 0.5593 - accuracy: 0.8755 - val_loss: 0.6132 - val_accuracy: 0.8668
# Epoch 81/125
# 625/625 [==============================] - 32s 51ms/step - loss: 0.5646 - accuracy: 0.8744 - val_loss: 0.6107 - val_accuracy: 0.8595
# Epoch 82/125
# 625/625 [==============================] - 31s 50ms/step - loss: 0.5624 - accuracy: 0.8757 - val_loss: 0.6715 - val_accuracy: 0.8434
# Epoch 83/125
# 625/625 [==============================] - 34s 54ms/step - loss: 0.5623 - accuracy: 0.8751 - val_loss: 0.6671 - val_accuracy: 0.8541
# Epoch 84/125
# 625/625 [==============================] - 32s 51ms/step - loss: 0.5646 - accuracy: 0.8734 - val_loss: 0.6501 - val_accuracy: 0.8520
# Epoch 85/125
# 625/625 [==============================] - 33s 52ms/step - loss: 0.5656 - accuracy: 0.8748 - val_loss: 0.6895 - val_accuracy: 0.8489
# Epoch 86/125
# 625/625 [==============================] - 33s 52ms/step - loss: 0.5654 - accuracy: 0.8763 - val_loss: 0.6975 - val_accuracy: 0.8406
# Epoch 87/125
# 625/625 [==============================] - 32s 52ms/step - loss: 0.5696 - accuracy: 0.8742 - val_loss: 0.6841 - val_accuracy: 0.8396
# Epoch 88/125
# 625/625 [==============================] - 32s 51ms/step - loss: 0.5606 - accuracy: 0.8779 - val_loss: 0.6199 - val_accuracy: 0.8624
# Epoch 89/125
# 625/625 [==============================] - 32s 52ms/step - loss: 0.5552 - accuracy: 0.8781 - val_loss: 0.6304 - val_accuracy: 0.8591
# Epoch 90/125
# 625/625 [==============================] - 33s 53ms/step - loss: 0.5610 - accuracy: 0.8776 - val_loss: 0.6477 - val_accuracy: 0.8559
# Epoch 91/125
# 625/625 [==============================] - 33s 53ms/step - loss: 0.5544 - accuracy: 0.8824 - val_loss: 0.6570 - val_accuracy: 0.8506
# Epoch 92/125
# 625/625 [==============================] - 35s 56ms/step - loss: 0.5566 - accuracy: 0.8805 - val_loss: 0.6799 - val_accuracy: 0.8457
# Epoch 93/125
# 625/625 [==============================] - 33s 53ms/step - loss: 0.5610 - accuracy: 0.8791 - val_loss: 0.6459 - val_accuracy: 0.8538
# Epoch 94/125
# 625/625 [==============================] - 32s 52ms/step - loss: 0.5600 - accuracy: 0.8798 - val_loss: 0.6270 - val_accuracy: 0.8561
# Epoch 95/125
# 625/625 [==============================] - 33s 53ms/step - loss: 0.5556 - accuracy: 0.8816 - val_loss: 0.6210 - val_accuracy: 0.8625
# Epoch 96/125
# 625/625 [==============================] - 34s 54ms/step - loss: 0.5508 - accuracy: 0.8824 - val_loss: 0.6398 - val_accuracy: 0.8552
# Epoch 97/125
# 625/625 [==============================] - 34s 54ms/step - loss: 0.5562 - accuracy: 0.8822 - val_loss: 0.6495 - val_accuracy: 0.8559
# Epoch 98/125
# 625/625 [==============================] - 34s 54ms/step - loss: 0.5522 - accuracy: 0.8845 - val_loss: 0.6596 - val_accuracy: 0.8519
# Epoch 99/125
# 625/625 [==============================] - 34s 55ms/step - loss: 0.5482 - accuracy: 0.8859 - val_loss: 0.6306 - val_accuracy: 0.8581
# Epoch 100/125
# 625/625 [==============================] - 33s 53ms/step - loss: 0.5500 - accuracy: 0.8837 - val_loss: 0.6484 - val_accuracy: 0.8586
# Epoch 101/125
# 625/625 [==============================] - 34s 54ms/step - loss: 0.5554 - accuracy: 0.8814 - val_loss: 0.6744 - val_accuracy: 0.8520
# Epoch 102/125
# 625/625 [==============================] - 34s 55ms/step - loss: 0.5490 - accuracy: 0.8842 - val_loss: 0.6762 - val_accuracy: 0.8519
# Epoch 103/125
# 625/625 [==============================] - 34s 54ms/step - loss: 0.5444 - accuracy: 0.8870 - val_loss: 0.6465 - val_accuracy: 0.8604
# Epoch 104/125
# 625/625 [==============================] - 33s 54ms/step - loss: 0.5446 - accuracy: 0.8855 - val_loss: 0.7200 - val_accuracy: 0.8416
# Epoch 105/125
# 625/625 [==============================] - 35s 55ms/step - loss: 0.5446 - accuracy: 0.8869 - val_loss: 0.6170 - val_accuracy: 0.8669
# Epoch 106/125
# 625/625 [==============================] - 34s 54ms/step - loss: 0.5416 - accuracy: 0.8877 - val_loss: 0.7142 - val_accuracy: 0.8399
# Epoch 107/125
# 625/625 [==============================] - 33s 53ms/step - loss: 0.5465 - accuracy: 0.8864 - val_loss: 0.6454 - val_accuracy: 0.8649
# Epoch 108/125
# 625/625 [==============================] - 33s 52ms/step - loss: 0.5475 - accuracy: 0.8877 - val_loss: 0.6534 - val_accuracy: 0.8592
# Epoch 109/125
# 625/625 [==============================] - 33s 52ms/step - loss: 0.5409 - accuracy: 0.8875 - val_loss: 0.7648 - val_accuracy: 0.8315
# Epoch 110/125
# 625/625 [==============================] - 33s 53ms/step - loss: 0.5384 - accuracy: 0.8877 - val_loss: 0.6393 - val_accuracy: 0.8615
# Epoch 111/125
# 625/625 [==============================] - 33s 53ms/step - loss: 0.5450 - accuracy: 0.8876 - val_loss: 0.6853 - val_accuracy: 0.8496
# Epoch 112/125
# 625/625 [==============================] - 35s 56ms/step - loss: 0.5456 - accuracy: 0.8870 - val_loss: 0.6772 - val_accuracy: 0.8510
# Epoch 113/125
# 625/625 [==============================] - 34s 54ms/step - loss: 0.5460 - accuracy: 0.8889 - val_loss: 0.6519 - val_accuracy: 0.8557
# Epoch 114/125
# 625/625 [==============================] - 34s 54ms/step - loss: 0.5477 - accuracy: 0.8869 - val_loss: 0.6651 - val_accuracy: 0.8561
# Epoch 115/125
# 625/625 [==============================] - 34s 54ms/step - loss: 0.5378 - accuracy: 0.8908 - val_loss: 0.6816 - val_accuracy: 0.8562
# Epoch 116/125
# 625/625 [==============================] - 34s 55ms/step - loss: 0.5438 - accuracy: 0.8888 - val_loss: 0.6254 - val_accuracy: 0.8664
# Epoch 117/125
# 625/625 [==============================] - 33s 53ms/step - loss: 0.5366 - accuracy: 0.8912 - val_loss: 0.6546 - val_accuracy: 0.8637
# Epoch 118/125
# 625/625 [==============================] - 34s 55ms/step - loss: 0.5321 - accuracy: 0.8927 - val_loss: 0.6699 - val_accuracy: 0.8596
# Epoch 119/125
# 625/625 [==============================] - 34s 55ms/step - loss: 0.5409 - accuracy: 0.8918 - val_loss: 0.6346 - val_accuracy: 0.8638
# Epoch 120/125
# 625/625 [==============================] - 33s 53ms/step - loss: 0.5376 - accuracy: 0.8911 - val_loss: 0.6680 - val_accuracy: 0.8505
# Epoch 121/125
# 625/625 [==============================] - 36s 58ms/step - loss: 0.5365 - accuracy: 0.8916 - val_loss: 0.6673 - val_accuracy: 0.8584
# Epoch 122/125
# 625/625 [==============================] - 34s 54ms/step - loss: 0.5429 - accuracy: 0.8893 - val_loss: 0.6714 - val_accuracy: 0.8604
# Epoch 123/125
# 625/625 [==============================] - 34s 54ms/step - loss: 0.5345 - accuracy: 0.8936 - val_loss: 0.6618 - val_accuracy: 0.8592
# Epoch 124/125
# 625/625 [==============================] - 35s 55ms/step - loss: 0.5390 - accuracy: 0.8930 - val_loss: 0.6718 - val_accuracy: 0.8545
# Epoch 125/125
# 625/625 [==============================] - 34s 54ms/step - loss: 0.5337 - accuracy: 0.8945 - val_loss: 0.7348 - val_accuracy: 0.8454

# %% [markdown]
# # **Langkah 9: Mengevaluasi model pada set tes**

# %%
scores = model.evaluate(X_test, y_test)
# Out:
# 313/313 [==============================] - 2s 6ms/step - loss: 0.7695 - accuracy: 0.8398

# %% [markdown]
# # **Langkah 10: Melakukan prediksi**

# %%
pd.DataFrame(history.history).plot()
# Out:
# <Axes: >

# %% [markdown]
# # **Langkah 11: Tampilkan laporan klasifikasi**

# %%
scores = model.evaluate(X_test, y_test)
pred = model.predict(X_test)
labels = ['Airplane', 'Automobile', 'Bird', 'Cat', 'Deer', 'Dog', 'Frog', 'Horse', 'Ship', 'Truck']
y_pred = np.argmax(pred, axis=1)
y_true = np.argmax(y_test, axis=1)
errors = y_pred - y_true != 0
print(classification_report(y_true, y_pred))
# Out:
# 313/313 [==============================] - 2s 6ms/step - loss: 0.7695 - accuracy: 0.8398
# 313/313 [==============================] - 1s 4ms/step
#               precision    recall  f1-score   support
#
#            0       0.93      0.82      0.87      1000
#            1       0.92      0.92      0.92      1000
#            2       0.85      0.76      0.80      1000
#            3       0.81      0.58      0.67      1000
#            4       0.84      0.82      0.83      1000
#            5       0.77      0.80      0.78      1000
#            6       0.70      0.97      0.81      1000
#            7       0.92      0.89      0.90      1000
#            8       0.95      0.88      0.92      1000
#            9       0.80      0.95      0.87      1000
#
#     accuracy                           0.84     10000
#    macro avg       0.85      0.84      0.84     10000
# weighted avg       0.85      0.84      0.84     10000

# %% [markdown]
# # **Langkah 12: Menampilkan visualisasi hasil prediksi**

# %%
fig, axes = plt.subplots(5, 5, figsize=(12,12))
axes = axes.ravel()
for i in np.arange(25):
    axes[i].imshow(X_test[i])
    axes[i].set_title('True: %s \nPredict: %s' % (labels[y_true[i]], labels[y_pred[i]]))
    axes[i].axis('off')
    plt.subplots_adjust(wspace=1)

# %% [markdown]
# -  Buatlah model CNN untuk klasifikasi dataset MNIST.

# %% [markdown]
# # **Langkah 1: Memuat Dataset MNIST**

# %%
import tensorflow as tf
from tensorflow.keras.datasets import mnist

# Memuat dataset MNIST
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step

# %% [markdown]
# # **Langkah 2: Normalisasi Gambar ke Rentang [0, 1]**

# %%
# Normalisasi gambar ke rentang [0, 1]
train_images, test_images = train_images / 255.0, test_images / 255.0

# %% [markdown]
# # **Langkah 3: Mengonversi Label ke Format One-Hot Encoding**

# %%
# Perbaikan: Mengimpor to_categorical dari tensorflow.keras.utils
from tensorflow.keras.utils import to_categorical

# Mengonversi label ke format one-hot encoding
train_labels = to_categorical(train_labels, num_classes=10)
test_labels = to_categorical(test_labels, num_classes=10)

# %% [markdown]
# # **Langkah 4: Menampilkan Informasi tentang Dataset**

# %%
# Menampilkan informasi tentang dataset
print("Jumlah data latihan:", len(train_images))
print("Jumlah data pengujian:", len(test_images))
print("Ukuran gambar:", train_images[0].shape)
# Out:
# Jumlah data latihan: 60000
# Jumlah data pengujian: 10000
# Ukuran gambar: (28, 28)

# %% [markdown]
# # **Langkah 5: Membangun Model**

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

# Membangun model
model = Sequential()
model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=(28,28,1)))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(64, kernel_size=(3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(10, activation='softmax'))

# %% [markdown]
# # **Langkah 6: Mengompilasi Model**

# %%
# Mengompilasi model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# # **Langkah 7: Menampilkan Ringkasan Model**

# %%
# Menampilkan ringkasan model
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_5 (Conv2D)           (None, 26, 26, 32)        320
#
#  max_pooling2d_3 (MaxPoolin  (None, 13, 13, 32)        0
#  g2D)
#
#  conv2d_6 (Conv2D)           (None, 11, 11, 64)        18496
#
#  max_pooling2d_4 (MaxPoolin  (None, 5, 5, 64)          0
#  g2D)
#
#  flatten_1 (Flatten)         (None, 1600)              0
#
#  dense_4 (Dense)             (None, 128)               204928
#
#  dropout_6 (Dropout)         (None, 128)               0
#
#  dense_5 (Dense)             (None, 64)                8256
#
#  dropout_7 (Dropout)         (None, 64)                0
#
#  dense_6 (Dense)             (None, 10)                650
#
# =================================================================
# Total params: 232650 (908.79 KB)
# Trainable params: 232650 (908.79 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# # **Langkah 8: Melatih Model**

# %%
# Melatih model
history = model.fit(train_images, train_labels, epochs=10, batch_size=128, verbose=2, validation_split=0.3)
# Out:
# Epoch 1/10
# 329/329 - 5s - loss: 0.3880 - accuracy: 0.8780 - val_loss: 0.1029 - val_accuracy: 0.9684 - 5s/epoch - 16ms/step
# Epoch 2/10
# 329/329 - 2s - loss: 0.0954 - accuracy: 0.9714 - val_loss: 0.0561 - val_accuracy: 0.9828 - 2s/epoch - 6ms/step
# Epoch 3/10
# 329/329 - 2s - loss: 0.0634 - accuracy: 0.9811 - val_loss: 0.0512 - val_accuracy: 0.9848 - 2s/epoch - 5ms/step
# Epoch 4/10
# 329/329 - 2s - loss: 0.0507 - accuracy: 0.9850 - val_loss: 0.0533 - val_accuracy: 0.9848 - 2s/epoch - 6ms/step
# Epoch 5/10
# 329/329 - 2s - loss: 0.0445 - accuracy: 0.9860 - val_loss: 0.0443 - val_accuracy: 0.9881 - 2s/epoch - 6ms/step
# Epoch 6/10
# 329/329 - 2s - loss: 0.0346 - accuracy: 0.9901 - val_loss: 0.0469 - val_accuracy: 0.9873 - 2s/epoch - 6ms/step
# Epoch 7/10
# 329/329 - 2s - loss: 0.0317 - accuracy: 0.9902 - val_loss: 0.0387 - val_accuracy: 0.9886 - 2s/epoch - 7ms/step
# Epoch 8/10
# 329/329 - 2s - loss: 0.0237 - accuracy: 0.9927 - val_loss: 0.0401 - val_accuracy: 0.9901 - 2s/epoch - 5ms/step
# Epoch 9/10
# 329/329 - 2s - loss: 0.0216 - accuracy: 0.9931 - val_loss: 0.0410 - val_accuracy: 0.9899 - 2s/epoch - 6ms/step
# Epoch 10/10
# 329/329 - 2s - loss: 0.0201 - accuracy: 0.9936 - val_loss: 0.0414 - val_accuracy: 0.9900 - 2s/epoch - 6ms/step

# %% [markdown]
# # **Langkah 9: Plot Sejarah Pelatihan**

# %%
import matplotlib.pyplot as plt

# Plot sejarah pelatihan
plt.figure(figsize=(14, 5))

plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Akurasi Pelatihan')
plt.plot(history.history['val_accuracy'], label='Akurasi Validasi')
plt.legend(loc='lower right')
plt.title('Akurasi Pelatihan dan Validasi')

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Loss Pelatihan')
plt.plot(history.history['val_loss'], label='Loss Validasi')
plt.legend(loc='upper right')
plt.title('Loss Pelatihan dan Validasi')
# Out:
# Text(0.5, 1.0, 'Loss Pelatihan dan Validasi')

# %% [markdown]
# # **Langkah 10: Evaluasi Model pada Kumpulan Data Uji**

# %%
# Evaluasi model pada kumpulan data uji
validation_loss, validation_accuracy = model.evaluate(test_images, test_labels, verbose=False)
print("Loss Validasi:", validation_loss)
print("Akurasi Validasi:", validation_accuracy)
# Out:
# Loss Validasi: 0.029380908235907555
# Akurasi Validasi: 0.9914000034332275

# %% [markdown]
# # **Langkah 11: Menghasilkan Nilai Prediksi pada Kumpulan Data Uji**

# %%
# Menghasilkan nilai prediksi pada kumpulan data uji
y_pred_enc = model.predict(test_images)
# Out:
# 313/313 [==============================] - 1s 3ms/step

# %% [markdown]
# # **Langkah 12: Mendekode Nilai Prediksi**

# %%
# Mendekode nilai prediksi
y_pred = [np.argmax(i) for i in y_pred_enc]

# %% [markdown]
# # **Langkah 13: Menampilkan Laporan Klasifikasi**

# %%
# Menampilkan laporan klasifikasi
print(classification_report(np.argmax(test_labels, axis=1), y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99       980
#            1       1.00      1.00      1.00      1135
#            2       0.98      1.00      0.99      1032
#            3       0.99      0.99      0.99      1010
#            4       0.99      0.99      0.99       982
#            5       0.99      0.99      0.99       892
#            6       1.00      0.99      0.99       958
#            7       1.00      0.98      0.99      1028
#            8       0.98      0.99      0.99       974
#            9       0.99      0.99      0.99      1009
#
#     accuracy                           0.99     10000
#    macro avg       0.99      0.99      0.99     10000
# weighted avg       0.99      0.99      0.99     10000

# %% [markdown]
# # **Langkah 14: Membuat Matriks Konfusi dan Menampilkannya dengan Heatmap**

# %%
import seaborn as sns
from sklearn.metrics import confusion_matrix

# Membuat matriks konfusi dan menampilkannya dengan heatmap
fig, ax = plt.subplots(figsize=(7, 7))
sns.heatmap(confusion_matrix(np.argmax(test_labels, axis=1), y_pred), annot=True, cbar=False, fmt='1d', cmap='Blues', ax=ax)
ax.set_title('Matriks Konfusi', loc='left', fontsize=16)
ax.set_xlabel('Prediksi')
ax.set_ylabel('Aktual')
# Out:
# Text(58.222222222222214, 0.5, 'Aktual')

# %% [markdown]
# # **Langkah 15: Menampilkan Target yang Diprediksi pada Setiap Gambar (Label di atas gambar adalah label yang diprediksi)**

# %%
# Menampilkan target yang diprediksi pada setiap gambar
# (label di atas gambar adalah label yang diprediksi)
plt.figure(figsize=(18, 12))
for ind, row in enumerate(test_images[:15]):
    plt.subplot(3, 5, ind+1)
    plt.title(y_pred[ind])
    img = row.reshape(28, 28)
    plt.axis('off')
    plt.imshow(img, cmap='cividis')
